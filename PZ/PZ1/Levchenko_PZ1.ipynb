# %% [markdown]
# # 📌 Індивідуальне завдання
#
# **Номер студента в списку:** `12`
# **Задачі для розв’язання:** `12`, `12 + 5 - 15 = 2` (з циклічним переходом, якщо потрібно)
#
# ---
#
# ## ✅ Завдання 1
# ### Дано:
# - 𝑓(𝑛) = 200𝑛³ + 15
# - 𝑔(𝑛) = 𝑛³
#
# ### Потрібно довести:
# **𝑓(𝑛) = O(𝑔(𝑛))**
#
# ---
#
# ### ✍️ Розв’язання:
#
# Формально:
# - f(n) = 200 * n³ + 15
# - g(n) = n³
#
# Оцінюємо складність f(n):
#
# При великих n, доданок `+15` незначний у порівнянні з `200n³`.
# Можемо записати:
#
# > **f(n) ≤ 201 * n³ при n ≥ 1**
#
# Отже, існує така константа `C = 201` і `n₀ = 1`, що:
# > **f(n) ≤ C * g(n), при n ≥ n₀**
#
# ✅ **Висновок:**
# f(n) = **O(n³)** → тобто **f(n) = O(g(n))**
#
# ---
#
# ## ✅ Завдання 2
# ### Дано:
# - f(n) = 7n²
#
# ### Потрібно знайти:
# **Асимптотичну складність у O-нотації**
#
# ---
#
# ### ✍️ Розв’язання:
#
# > f(n) = 7 * n²
#
# Коефіцієнт `7` не впливає на порядок зростання.
# Маємо:
#
# > **f(n) = O(n²)**
#
# ✅ **Висновок:**
# Асимптотична складність функції — **O(n²)**
#
# ---
#
# # 📘 Контрольні питання
#
# ---
#
# ### **1. Що таке асимптотична складність алгоритму?**
#
# Асимптотична складність — це характеристика ефективності алгоритму,
# яка описує, як змінюється час виконання або використання памʼяті в залежності від розміру вхідних даних `n`,
# коли `n → ∞`.
#
# ---
#
# ### **2. Яким чином визначається O-нотація і яка її сутність?**
#
# O-нотація (Big O) — це математичний інструмент, що описує верхню межу зростання функції.
# Формально:
#
# > f(n) = O(g(n))
# > якщо ∃ C > 0 і n₀, такі що:
# > f(n) ≤ C * g(n), ∀ n ≥ n₀
#
# Суть — описати **найгірший випадок** зростання складності алгоритму.
#
# ---
#
# ### **3. Які основні правила використання O-нотації при аналізі алгоритмів?**
#
# - Ігноруються **константи**: O(5n) → O(n)
# - Враховується лише **найшвидше зростаючий доданок**: O(n² + n) → O(n²)
# - Показує лише **залежність від розміру вхідних даних**
# - Використовується для порівняння **ефективності алгоритмів**
#
# ---
#
# ### **4. Що означають вирази O(1), O(n), O(n²)?**
#
# - **O(1)** — постійна складність (незалежно від n)
# - **O(n)** — лінійна складність
# - **O(n²)** — квадратична складність (наприклад, вкладені цикли)
#
# ---
#
# ### **5. Як визначити асимптотичну складність за кодом або виразом?**
#
# 1. Проаналізувати **кількість і вкладеність циклів**
# 2. Врахувати **рекурсії**, якщо є
# 3. Вилучити незначущі доданки та **константи**
# 4. Обрати **найповільнішу частину**
# 5. Записати **Big-O** для основного етапу
#
# ---
